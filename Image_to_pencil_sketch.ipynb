# %% [markdown]
# <a href="https://colab.research.google.com/github/PasamAnu/LGMVIP-DATASCIENCE/blob/main/Image_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science Intern at Let's Grow More July 2022
#
# Beginner Level Task
#
# Image to pencil sketch
#
# Pasam Anu

# %%
from google.colab.patches import cv2_imshow

import cv2

# %%
img = cv2.imread('labrador.jpeg', 1)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F8DAA48F750>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F8DAA41CAD0>

# %%
img_invert = cv2.bitwise_not(img_gray)

cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F8DAA48F3D0>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F8DAA413C10>

# %%
def dodgeV2(x, y):

    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F8DAA437390>
